# %% [markdown]
# # Random Forest

# %% [markdown]
# - Random ---- Random selection ----- data
# - Forest ----- collectoin of trees

# %% [markdown]
# - sampling:
#     - with replacement
#     - without replacement

# %% [markdown]
# ![image.png](attachment:image.png)
