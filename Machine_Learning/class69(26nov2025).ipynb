# %% [markdown]
# # Decision Trees

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if occ == 'student':
    print('pubg')

else:
    if occ == 'programmer':
        if g == 'female':
            print('github')
        else:
            print('whatsapp')

# %%
if occ == 'student':
    print('pubg')
elif occ == 'programmer' and g = 'female':
    print('github')
elif occ == 'prog' and gender == 'male':
    print('whatsapp')
