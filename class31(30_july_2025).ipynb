# %%
class Battery:
    def __init__(self, company, voltage, capacity):
        # Attributes
        self.company = company  
        self.voltage = voltage  
        self.capacity = capacity  

    # Method
    def battery_info(self):
        print(f'Company: {self. company}\nVoltage:{self.voltage}\nCapacity: {self.capacity}')

# %%
battery_1 = Battery('osaka','12V', '55AH')

# %%
battery_1.company
# Out:
# 'osaka'

# %%
battery_1.company = 'Ags'

# %%
battery_1.company
# Out:
# 'Ags'

# %%
class Account:
    def __init__(self,bank_name, title, balance):
        self.title = title
        self.bank_name = bank_name
        self.balance = balance

# %%
kashan = Account('HBl', 'Kashan', 100000)

# %%
class Account:
    def __init__(self,bank_name, title, balance):
        self.title = title # Public 
        self._bank_name = bank_name #Protected
        self.balance = balance

    # Setter
    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        self.balance -= amount
    
    # Getter
    def show_balance(self):
        print(f'The balance is {self.balance}')

# %%
kashan.balance
# Out:
# 100000

# %%
kashan.balance += 20000

# %%
kashan.balance
# Out:
# 120000

# %%
kashan.balance -= 20000
kashan.balance
# Out:
# 100000

# %% [markdown]
# # Encapsulation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Account:
    def __init__(self,bank_name, title, balance):
        self.title = title
        self.bank_name = bank_name
        self.balance = balance

    # Setter
    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        self.balance -= amount
    
    # Getter
    def show_balance(self):
        print(f'The balance is {self.balance}')

# %%
kashan = Account('HBl', 'Kashan', 100000)

# %%
kashan.show_balance()
# Out:
# The balance is 100000

# %%
kashan.deposit(20000)

# %%
kashan.show_balance()
# Out:
# The balance is 120000

# %%
kashan.withdraw(20000)

# %%
kashan.show_balance()
# Out:
# The balance is 100000

# %% [markdown]
# # Access Specifiers in Python

# %%
class Account:
    def __init__(self,bank_name, title, balance):
        self.title = title # Public 
        self._BANK_NAME = bank_name #Protected
        self.__balance = balance # Private

    # Setter
    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        self.__balance -= amount
    
    # Getter
    def __show_balance(self):
        print(f'The balance is {self.__balance}')

# %%
kashan = Account('HBl', 'Kashan', 100000)

# %%
kashan.__show_balance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 kashan.__show_balance()
#
# AttributeError: 'Account' object has no attribute '__show_balance'

# %%
kashan._bank_name = 'Meezan'

# %%
kashan._bank_name
# Out:
# 'Meezan'

# %%
kashan.balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 kashan.balance
#
# AttributeError: 'Account' object has no attribute 'balance'

# %%
kashan.__balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 kashan.__balance
#
# AttributeError: 'Account' object has no attribute '__balance'

# %%
kashan.show_balance()
# Out:
# The balance is 100000

# %%
kashan.withdraw(20000)

# %%
kashan.show_balance()
# Out:
# The balance is 80000

# %%
kashan.deposit(20000)

# %%
kashan.show_balance()
# Out:
# The balance is 100000

# %%
kashan._BANK_NAME
# Out:
# 'HBl'

# %%
kashan._BANK_NAME = 'Meezan'

# %%
kashan._BANK_NAME
# Out:
# 'Meezan'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class CurrentAccount(Account):
    def __init__(self, bank_name, title, balance, age):
        super().__init__(bank_name, title, balance)

        self.age = age

# %%
ca.__show_balance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 ca.__show_balance()
#
# AttributeError: 'CurrentAccount' object has no attribute '__show_balance'

# %%
ca = CurrentAccount('hbl', 'kashan', 100000, 18)

# %%
ca._BANK_NAME
# Out:
# 'hbl'

# %%
ca.__balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 ca.__balance
#
# AttributeError: 'CurrentAccount' object has no attribute '__balance'
