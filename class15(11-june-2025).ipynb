# %%
if (0.1 + 0.2 == 0.3):
    print('True')
else:
    print('False')

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
def add_numbers(a, b):
    '''This function prints the sum of two numbers'''
    c = a + b
    print(c)

# %%
add_numbers(3, 4)
# Out:
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def display_message():
    print('This is a message')

# %%
display_message()
# Out:
# This is a message

# %%
def favorite_book(title):
    print(f'One of my favorite books is {title}')

# %%
favorite_book('Alice in Wonderland')
# Out:
# One of my favorite books is Alice in Wonderland

# %% [markdown]
# ## Positional Arguments

# %%
def add_numbers(b,a):
    '''This function prints the sum of two numbers'''
    c = a + b
    print(c)

# %%
add_numbers(2,3)
# Out:
# 5

# %%
def display_name(lname, fname):
    print(f'My name is {fname} {lname}')

# %%
display_name('ali', 'khan')
# Out:
# My name is khan ali

# %% [markdown]
# ## Keyword Arguments

# %%
display_name(fname = 'Ali', lname = 'Khan')
# Out:
# My name is Ali Khan

# %%
display_name(fname = 'Ali', 'khan')
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_7512\2306420144.py", line 1
#     display_name(fname = 'Ali', 'khan')
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
display_name('ali', lname = 'khan')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7512\3358232467.py in <module>
# ----> 1 display_name('ali', lname = 'khan')
#
# TypeError: display_name() got multiple values for argument 'lname'

# %%
display_name('khan', fname= 'ali')
# Out:
# My name is ali khan

# %%
def details(fname, lname, city):
    print(f'My name is {fname} {lname} and live in {city}')

# %%
details('ali', 'khan', 'karachi')
# Out:
# My name is ali khan and live in karachi

# %%
details(city='Karachi', lname = 'khan', fname = 'ali')
# Out:
# My name is ali khan and live in Karachi

# %%
details('ali', lname = 'khan', 'Karachi')
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_7512\532390599.py", line 1
#     details('ali', lname = 'khan', 'Karachi')
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
details('ali', 'Karachi', lname = 'khan')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7512\2751232332.py in <module>
# ----> 1 details('ali', 'Karachi', lname = 'khan')
#
# TypeError: details() got multiple values for argument 'lname'

# %%
details('ali', city ='Karachi', lname = 'khan')
# Out:
# My name is ali khan and live in Karachi

# %%
details('ali', 'khan', city = 'Karachi')
# Out:
# My name is ali khan and live in Karachi

# %% [markdown]
# ## Default Values

# %%
def display_name(fname, lname, city='Karachi'):
    print(f'My name is {fname} {lname},lives in {city}')

# %%
display_name('ali', 'khan')
# Out:
# My name is ali khan,lives in None

# %%
def display_name(city='Karachi', fname, lname):
    print(f'My name is {fname} {lname},lives in {city}')
# Out:
#   File "C:\Users\SMIT\AppData\Local\Temp\ipykernel_7512\451287082.py", line 1
#     def display_name(city='Karachi', fname, lname):
#                                             ^
# SyntaxError: non-default argument follows default argument

# %%
def make_shirt(size, text):
    print(f'A {size} {text}')

# %%
make_shirt('large', 'Elephant')
# Out:
# A large Elephant

# %%
make_shirt(text='elephant', size = 'Medium')
# Out:
# A Medium elephant

# %%
def make_shirt(size = 'large', text='I love python'):
    print(f'{text} with {size} tshirt')

# %%
make_shirt()
# Out:
# I love python with large tshirt

# %%
make_shirt(size = 'medium')
# Out:
# I love python with medium tshirt

# %%
make_shirt(text = 'I love js')
# Out:
# I love js with large tshirt

# %%
def describe_city(city, country):
    print(f'{city} is in {country}')

# %%
describe_city('Karachi', 'Pakistan')
# Out:
# Karachi is in Pakistan

# %%
def describe_city(city, country='Pakistan'):
    print(f'{city} is in {country}')

# %%
describe_city('Newyork')
# Out:
# Newyork is in Pakistan

# %%
result = describe_city('Newyork')
# Out:
# Newyork is in Pakistan

# %%
print(result)
# Out:
# None

# %%
def describe_city(city, country='Pakistan'):
    return f'{city} is in {country}'

# %%
result = describe_city('Larkana')

# %%
print(result.upper())
# Out:
# LARKANA IS IN PAKISTAN

# %%
def make_album(name, album):
    return {name: album}

# %%
make_album('Chahat bhai', 'Bado badi')
# Out:
# {'Chahat bhai': 'Bado badi'}
