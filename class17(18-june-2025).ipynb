# %% [markdown]
# # Passing an Arbitrary Number of Arguments

# %%
def icecream(flavor):
    return flavor

# %%
icecream('Chocolate')
# Out:
# 'Chocolate'

# %%
icecream('Chocoloate', 'mango')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13280\3727672203.py in <module>
# ----> 1 icecream('Chocoloate', 'mango')
#
# TypeError: icecream() takes 1 positional argument but 2 were given

# %%
def new_icecream(*flavor):
    return flavor

# %%
new_icecream('mango')
# Out:
# ('mango',)

# %%
new_icecream('mango', 'vanila')
# Out:
# ('mango', 'vanila')

# %%
new_icecream('mango','vanila', 'choco chip')
# Out:
# ('mango', 'vanila', 'choco chip')

# %%
def original_icecream(serving, scoop, *flavor):
    return f'Your ice cream having {serving} with {scoop} scoop with flavors {flavor}'

# %%
original_icecream('cup', 'double', 'choc', 'vanilla')
# Out:
# "Your ice cream having cup with double scoop with flavors ('choc', 'vanilla')"

# %%
"Your ice cream having cup with double scoop with flavor choc"
"Your ice cream having cup with double scoop with flavors choc and vanila"
"Your ice cream having cup with double scoop with flavors choc, vanila and mango"

# %%
def original_icecream(serving, scoop, *flavor):
#     print(len(flavor))
    if len(flavor) == 1:
        return f'''Your ice cream having {serving} with {scoop} scoop with flavor {flavor[0]}'''
    elif len(flavor) == 2:
        return f'Your ice cream having {serving} with {scoop} scoop with flavors {flavor[0]} and {flavor[1]}'
    elif len(flavor) > 2:
        return f'Your ice cream having {serving} with {scoop} scoop with flavors {", ".join(flavor[:-1])} and {flavor[-1]}'
    else:
        return f'Your ice cream having {serving} with {scoop} scoop with no flavor'

# %%
original_icecream('a', 'b')
# Out:
# 'Your ice cream having a with b scoop with no flavor'

# %%
('choc', 'van') ===> choc, van

# %%
flavors = ('choc', 'van')
', '.join(flavors)
# Out:
# 'choc, van'

# %%
', '.join(flavors)
# Out:
# 'choc, van'

# %%
def juice(size, serving, **ali):
    return f'size {size}, serving {serving}, shake {ali}'

# %%
juice('large', 'parcel', fruit = 'banana', dryfruit = 'almond', icecream = 'choc' )
# Out:
# "size large, serving parcel, shake {'fruit': 'banana', 'dryfruit': 'almond', 'icecream': 'choc'}"
