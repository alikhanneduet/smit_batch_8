# %%
def update_reason(filename,mode='a+'):
    flag = True
    result = {}
    while flag:
        name = input('Enter your name: ')
        if name.lower() == 'q':
            break
        reason = input('Why do you love programming? ')

        if reason.lower() == 'q':
            break
        if name in result:
            result[name].append(reason)
        else:
            result[name] = [reason]
    for key in result:
        with open(filename, mode) as f:
            f.write(f'{key}: ')
            f.write(f'{', '.join(result[key])}\n')

# %%
update_reason('record.txt')

# %%
result = {}
while True:
    name = input('enter your name')
    if name.lower() == 'q':
        break 
    reason = input('enter reason') 
    if reason.lower() == 'q':
        break 
    if name in result:
        result[name].append(reason)
    else:
        result[name] = [reason]
    
# for name, reason in result.items():

    
    print(f'{name}: {reason}')
# Out:
# ali khan: i love code
# taha bhai: i dont know
# faizan bhai: faizan bhai ka faizan
# ali khan: dubara se

# %%
print(result)
# Out:
# {'ali khan': ['i love code', 'dubara se'], 'taha bhai': ['i dont know'], 'faizan bhai': ['faizan bhai ka faizan']}

# %%
{'ali khan': ['i love code', 'dubara se'], 'taha bhai': ['i dont know'], 'faizan bhai': ['faizan bhai ka faizan']}

# %%
{
    'ali khan': ['i love code','i am human'],
    'taha khan': ['what is this','where is my reason']

}

# %%
', '.join(['what is this man', 'dkljfkdjfkdjfkd'])
# Out:
# 'what is this man, dkljfkdjfkdjfkd'

# %%
# Final code

def update_reason(filename,mode='a+'):
    flag = True
    result = {}
    while flag:
        name = input('Enter your name: ')
        if name.lower() == 'q':
            break
        reason = input('Why do you love programming? ')

        if reason.lower() == 'q':
            break
        if name in result:
            result[name].append(reason)
        else:
            result[name] = [reason]

    with open(filename, mode) as f:
        for key in result:
            f.write(f'{key}: ')
            f.write(f'{', '.join(result[key])}\n')

# %%
update_reason('record.txt')
